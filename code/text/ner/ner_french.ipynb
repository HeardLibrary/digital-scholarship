# %% [markdown]
# # French Named Entity Recognition (NER) using Spacy
#
# References:
# French models (based on news) https://spacy.io/models/fr/
#
# NER code examples https://www.geeksforgeeks.org/python-named-entity-recognition-ner-using-spacy/

# %%
# Run this cell only once per session to download the French "news" model
#!python -m spacy download fr_core_news_sm # small model 15 MB
# !python -m spacy download fr_core_news_lg # large model 545 MB

# %%
# ner_french.ipynb, a Python script for doing named entity recognition on French text.

# (c) 2024 Vanderbilt University. This program is released under a GNU General Public License v3.0 http://www.gnu.org/licenses/gpl-3.0
# Author: Steve Baskauf

version = '0.0.1'
created = '2024-02-19'

# ------------------
# Imports
# ------------------

import spacy
nlp = spacy.load("fr_core_news_lg")

# %% [markdown]
# Test using hard-coded text. Analyze and show parts of speech.

# %%
text = '''L'empoisonnement a toujours excité l'horreur et l'indignation,
non-sculement parce qu'il frappe dans l'ombre des victimes fata-
lement vouées à la mort, mais parce qu'il répand l'effroi sur la
société tout entière. Cette frénésie éclata sous Louis XIV, après
les guerres civiles de la régence. La Fronde, en jetant les hommes
sur les champs de bataille, avait laissé aux femmes une liberté
qu'elles perdirent avec la paix ; les maris revinrent chez euv
vieillis, brutaux et blasés par la licence des armées et par les
amours de passage; en outre, les communications fréquentes avec
l'Espagne avaient mis la jalousie à la mode; sans être prison-
nières, les femmes étaient très-renfermées et fort surveillées;
même à la cour, elles ne communiquaient guère avec les
hommes qu'à certains jours de réception et dans les bals, et alors
la conversation roulait exclusivement sur l'amour et les histoires
scandaleuses; un entretien sérieux sur des matières graves les eût
exposées à passer pour des précieuses, et Louis XIV ne les aimait
pas; d'ailleurs il donnait l'exemple de la galanterie, et tous les
hommes cherchaient à l'imiter. Quel combat devait se livrer dans
le caur des femmes lorsque, rentrées chez elles, au lieu des
hommages prodigués par leurs adorateurs, elles ne trouvaient au
logis que la solitude ou les brutalités et les transports jaloux de
leurs maris ! Les habitudes de l'ancieune liberté, et la facilité de
mncurs qu'avait encouragée Mazarin pendant la Fronde, les
avaient mal préparées à cette gêne dont rien ne diminuait l'ennui;
les passions comprimées devinrent plus violentes, beaucoup de'''

doc = nlp(text)
#print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# L' DET det
# empoisonnement NOUN nsubj
# a AUX aux:tense
# toujours ADV advmod
# excité VERB ROOT
# l' DET det
# horreur NOUN dep
# et CCONJ cc
# l' DET det
# indignation NOUN conj
# , PUNCT punct
#
#  SPACE dep
# non-sculement ADV advmod
# parce SCONJ mark
# qu' SCONJ fixed
# il PRON expl:subj
# frappe VERB advcl
# dans ADP case
# l' DET det
# ombre NOUN obl:mod
# des ADP case
# victimes NOUN nmod
# fata- VERB amod
#
#  SPACE dep
# lement ADV advmod
# vouées VERB acl
# à ADP case
# la DET det
# mort NOUN obl:arg
# , PUNCT punct
# mais CCONJ cc
# parce SCONJ mark
# qu' SCONJ fixed
# il PRON nsubj
# répand VERB conj
# l' DET det
# effroi NOUN obj
# sur ADP case
# la DET det
#
#  SPACE dep
# société NOUN obl:mod
# tout ADV advmod
# entière ADJ amod
# . PUNCT punct
# Cette DET det
# frénésie NOUN ROOT
# éclata VERB acl
# sous ADP case
# Louis PROPN obl:mod
# XIV PROPN flat:name
# , PUNCT punct
# après ADP case
#
#  SPACE dep
# les DET det
# guerres NOUN nmod
# civiles ADJ amod
# de ADP case
# la DET det
# régence NOUN nmod
# . PUNCT punct
# La DET det
# Fronde PROPN nsubj
# , PUNCT punct
# en ADP mark
# jetant VERB acl
# les DET det
# hommes NOUN obj
#
#  SPACE dep
# sur ADP case
# les DET det
# champs NOUN nmod
# de ADP case
# bataille NOUN nmod
# , PUNCT punct
# avait AUX aux:tense
# laissé VERB ROOT
# aux ADP case
# femmes NOUN obl:arg
# une DET det
# liberté NOUN obj
#
#  SPACE dep
# qu' PRON obj
# elles PRON nsubj
# perdirent VERB acl:relcl
# avec ADP case
# la DET det
# paix NOUN obl:arg
# ; PUNCT punct
# les DET det
# maris NOUN nsubj
# revinrent VERB ROOT
# chez ADP case
# euv PROPN obl:arg
#
#  SPACE dep
# vieillis NOUN nmod
# , PUNCT punct
# brutaux ADJ conj
# et CCONJ cc
# blasés VERB conj
# par ADP case
# la DET det
# licence NOUN obl:agent
# des ADP case
# armées NOUN nmod
# et CCONJ cc
# par ADP case
# les DET det
#
#  SPACE dep
# amours NOUN conj
# de ADP case
# passage NOUN nmod
# ; PUNCT punct
# en ADP advmod
# outre ADP fixed
# , PUNCT punct
# les DET det
# communications NOUN nsubj
# fréquentes ADJ amod
# avec ADP case
#
#  SPACE dep
# l' DET det
# Espagne PROPN nmod
# avaient AUX aux:tense
# mis VERB ROOT
# la DET det
# jalousie NOUN obj
# à ADP case
# la DET det
# mode NOUN nmod
# ; PUNCT punct
# sans ADP mark
# être AUX cop
# prison- VERB advcl
#
#  SPACE dep
# nières X dep
# , PUNCT punct
# les DET det
# femmes NOUN nsubj
# étaient AUX cop
# très ADV advmod
# - PUNCT dep
# renfermées VERB acl
# et CCONJ cc
# fort ADV advmod
# surveillées VERB conj
# ; PUNCT punct
#
#  SPACE dep
# même ADV advmod
# à ADP case
# la DET det
# cour NOUN obl:arg
# , PUNCT punct
# elles PRON nsubj
# ne ADV advmod
# communiquaient VERB ROOT
# guère ADV advmod
# avec ADP case
# les DET det
#
#  SPACE dep
# hommes NOUN obl:arg
# qu' SCONJ mark
# à ADP case
# certains DET det
# jours NOUN obl:mod
# de ADP case
# réception NOUN nmod
# et CCONJ cc
# dans ADP case
# les DET det
# bals NOUN conj
# , PUNCT punct
# et CCONJ cc
# alors ADV advmod
#
#  SPACE dep
# la DET det
# conversation NOUN nsubj
# roulait VERB acl
# exclusivement ADV advmod
# sur ADP case
# l' DET det
# amour NOUN obl:arg
# et CCONJ cc
# les DET det
# histoires NOUN conj
#
#  SPACE dep
# scandaleuses NOUN nmod
# ; PUNCT punct
# un DET det
# entretien NOUN ROOT
# sérieux ADJ amod
# sur ADP case
# des DET det
# matières NOUN nmod
# graves ADJ amod
# les PRON obj
# eût AUX aux:tense
#
#  SPACE dep
# exposées VERB acl
# à ADP mark
# passer VERB xcomp
# pour ADP case
# des DET det
# précieuses NOUN obl:arg
# , PUNCT punct
# et CCONJ cc
# Louis PROPN nsubj
# XIV ADJ flat:name
# ne ADV advmod
# les PRON obj
# aimait VERB conj
#
#  SPACE dep
# pas ADV advmod
# ; PUNCT punct
# d' ADP case
# ailleurs ADV obl:mod
# il PRON nsubj
# donnait VERB ROOT
# l' DET det
# exemple NOUN obj
# de ADP case
# la DET det
# galanterie NOUN nmod
# , PUNCT punct
# et CCONJ cc
# tous ADJ amod
# les DET det
#
#  SPACE dep
# hommes NOUN nsubj
# cherchaient VERB conj
# à ADP mark
# l' PRON obj
# imiter VERB xcomp
# . PUNCT punct
# Quel DET det
# combat NOUN nsubj
# devait VERB ROOT
# se PRON expl:comp
# livrer VERB xcomp
# dans ADP case
#
#  SPACE dep
# le DET det
# caur NOUN obl:mod
# des ADP case
# femmes NOUN nmod
# lorsque SCONJ mark
# , PUNCT punct
# rentrées VERB advcl
# chez ADP case
# elles PRON obl:mod
# , PUNCT punct
# au ADP case
# lieu NOUN obl:mod
# des ADP case
#
#  SPACE dep
# hommages NOUN nmod
# prodigués VERB acl
# par ADP case
# leurs DET det
# adorateurs NOUN obl:agent
# , PUNCT punct
# elles PRON nsubj
# ne ADV advmod
# trouvaient VERB advcl
# au ADP case
#
#  SPACE dep
# logis NOUN obl:arg
# que SCONJ mark
# la DET det
# solitude NOUN nmod
# ou CCONJ cc
# les DET det
# brutalités NOUN conj
# et CCONJ cc
# les DET det
# transports NOUN conj
# jaloux ADJ amod
# de ADP case
#
#  SPACE dep
# leurs DET det
# maris NOUN nmod
# ! PUNCT punct
# Les DET det
# habitudes NOUN nsubj
# de ADP case
# l' DET det
# ancieune ADJ nmod
# liberté NOUN nmod
# , PUNCT punct
# et CCONJ cc
# la DET det
# facilité NOUN conj
# de ADP case
#
#  SPACE dep
# mncurs NOUN nmod
# qu' PRON obj
# avait AUX aux:tense
# encouragée VERB acl:relcl
# Mazarin PROPN dep
# pendant ADP case
# la DET det
# Fronde PROPN obl:mod
# , PUNCT punct
# les DET det
#
#  SPACE dep
# avaient AUX aux:tense
# mal ADV obj
# préparées VERB advcl
# à ADP case
# cette DET det
# gêne NOUN obl:arg
# dont PRON iobj
# rien PRON nsubj
# ne ADV advmod
# diminuait VERB acl:relcl
# l' DET det
# ennui NOUN obj
# ; PUNCT punct
#
#  SPACE dep
# les DET det
# passions NOUN nsubj
# comprimées VERB acl
# devinrent VERB ROOT
# plus ADV advmod
# violentes ADJ xcomp
# , PUNCT punct
# beaucoup ADV advmod
# de ADP punct

# %% [markdown]
# Show identified named entities. First column is the type of entity, second column is starting character within text string, third column is ending character within text string, fourth column is the identified named entity. Types (from https://spacy.io/models/fr) are:
#
# | code | description |
# | ---- | ----------- |
# | PER | persons |
# | ORG | organizations |
# | LOC | locaitons |
# | MISC | miscellaneous |

# %%
for ent in doc.ents:
    print(ent.label_, '\t', ent.start_char, '\t', ent.end_char, '\t', ent.text)
# Out:
# PER 	 242 	 251 	 Louis XIV
# MISC 	 294 	 303 	 La Fronde
# LOC 	 582 	 591 	 l'Espagne
# PER 	 1007 	 1016 	 Louis XIV
# PER 	 1452 	 1459 	 Mazarin
# MISC 	 1471 	 1477 	 Fronde

# %%
# map your google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Use a folder in the Google Drive called "ner_french"

# %%
directory_path = '/content/drive/MyDrive/ner_french/'
file_path = directory_path + 'rawTextSentHolly.txt'
with open(file_path, 'r') as file:
    raw_text = file.read()

# Need to analyze the text in smaller chunks. See error message when too large of a text blob was processed:
"""
Text of length 1203251 exceeds maximum of 1000000. The parser and NER models require roughly 1GB of temporary
memory per 100,000 characters in the input. This means long texts may cause memory allocation errors. If you're
not using the parser or NER, it's probably safe to increase the `nlp.max_length` limit. The limit is in number
of characters, so you can check whether your inputs are too long by checking `len(text)`.
"""

truncated_text = raw_text[:50000] # Analyze the first 50 000 characters

doc = nlp(truncated_text)
#print(doc)
for ent in doc.ents:
    print(ent.label_, '\t', ent.start_char, '\t', ent.end_char, '\t', ent.text)
