# %%
# zenodo_upload_tool.py, a Python script for uploading resources through the Zenodo API.

# (c) 2024 Vanderbilt University. This program is released under a GNU General Public License v3.0 http://www.gnu.org/licenses/gpl-3.0
# Author: Steve Baskauf

version = '0.0.1'
created = '2024-04-17'

# Zenodo API developer guide: https://developers.zenodo.org/#quickstart-upload

# -----------------------------------------
# Import modules.
# -----------------------------------------

import requests
from typing import List, Dict, Tuple, Optional, Any
from pathlib import Path
import json
from time import sleep

# -----------------------------------------
# Global variables.
# -----------------------------------------

# NOTE: The access tokens for the sandbox and production Zenodo instances are different. To use the sandbox, you need
# to log in to the sandbox instance and create a new access token.

#BASE_URL = 'https://zenodo.org/api'
BASE_URL = 'https://sandbox.zenodo.org/api' # for testing
HTTP_HEADER = {
    'Content-Type': 'application/json'
    }
#API_ACCESS_TOKEN_FILENAME = 'zenodo_bioimages_upload_access_token.txt'
API_ACCESS_TOKEN_FILENAME = 'zenodo_sandbox_access_token.txt'

# %% [markdown]
# Load the access token

# %%
# Read the API access token from a file in the home directory. The file should contain only the key and no other text.
home = str(Path.home()) # gets path to home directory; supposed to work for both Win and Mac
with open(home + '/' + API_ACCESS_TOKEN_FILENAME, 'r') as file:
    api_access_token = file.read().strip() # remove any leading or trailing white space or newlines
request_params = {'access_token': api_access_token}

# %% [markdown]
# Test code to see if the access token is working.

# %%
request_url = BASE_URL + '/deposit/depositions'
r = requests.get(request_url, params=request_params)
print(r.status_code)
print(json.dumps(r.json(), indent = 2))
# Out:
# 200
# [
#   {
#     "created": "2024-04-17T20:18:00.576346+00:00",
#     "modified": "2024-04-17T20:18:00.631979+00:00",
#     "id": 46387,
#     "conceptrecid": "46386",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46387",
#         "recid": 46387
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46387",
#       "html": "https://sandbox.zenodo.org/records/46387",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46387/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46387",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46387",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46387/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46387/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46387/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46387/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46387/actions/registerconceptdoi"
#     },
#     "record_id": 46387,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T19:13:56.576124+00:00",
#     "modified": "2024-04-17T19:13:56.805943+00:00",
#     "id": 46381,
#     "conceptrecid": "46380",
#     "doi": "10.5072/zenodo.46381",
#     "conceptdoi": "10.5072/zenodo.46380",
#     "doi_url": "https://doi.org/10.5072/zenodo.46381",
#     "metadata": {
#       "title": "Liatris squarrosa (L.) Michx. - flower - side",
#       "doi": "10.5072/zenodo.46381",
#       "publication_date": "2024-04-17",
#       "description": "Live plant image of a Liatris squarrosa (L.) Michx. (scaly blazing star) flower",
#       "access_right": "open",
#       "creators": [
#         {
#           "name": "Baskauf, Steven J.",
#           "affiliation": "Vanderbilt University"
#         }
#       ],
#       "license": "cc-by-4.0",
#       "imprint_publisher": "Zenodo",
#       "upload_type": "poster",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46381",
#         "recid": 46381
#       }
#     },
#     "title": "Liatris squarrosa (L.) Michx. - flower - side",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46381",
#       "html": "https://sandbox.zenodo.org/records/46381",
#       "doi": "https://doi.org/10.5072/zenodo.46381",
#       "parent_doi": "https://sandbox.zenodo.org/doi/10.5072/zenodo.46380",
#       "badge": "https://sandbox.zenodo.org/badge/doi/10.5072%2Fzenodo.46381.svg",
#       "conceptbadge": "https://sandbox.zenodo.org/badge/doi/10.5072%2Fzenodo.46380.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46381/files",
#       "thumb250": "https://sandbox.zenodo.org/record/46381/thumb250",
#       "thumbs": {
#         "10": "https://sandbox.zenodo.org/record/46381/thumb10",
#         "50": "https://sandbox.zenodo.org/record/46381/thumb50",
#         "100": "https://sandbox.zenodo.org/record/46381/thumb100",
#         "250": "https://sandbox.zenodo.org/record/46381/thumb250",
#         "750": "https://sandbox.zenodo.org/record/46381/thumb750",
#         "1200": "https://sandbox.zenodo.org/record/46381/thumb1200"
#       },
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46381",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46381",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46381/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46381/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46381/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46381/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46381/actions/registerconceptdoi",
#       "record": "https://sandbox.zenodo.org/api/records/46381",
#       "record_html": "https://sandbox.zenodo.org/record/46381",
#       "latest": "https://sandbox.zenodo.org/api/records/46381/versions/latest",
#       "latest_html": "https://sandbox.zenodo.org/record/46381/versions/latest"
#     },
#     "record_id": 46381,
#     "owner": 9120,
#     "files": [
#       {
#         "id": "308dc9c2-6937-41ac-bfb5-b971118d3344",
#         "filename": "lisq--flbracts36266.jpg",
#         "filesize": 612698,
#         "checksum": "07f590493c5aff505c886b2524126b0a",
#         "links": {
#           "self": "https://sandbox.zenodo.org/api/records/46381/files/308dc9c2-6937-41ac-bfb5-b971118d3344",
#           "download": "https://sandbox.zenodo.org/api/records/46381/draft/files/lisq--flbracts36266.jpg/content"
#         }
#       }
#     ],
#     "state": "done",
#     "submitted": true
#   },
#   {
#     "created": "2024-04-17T18:41:12.020093+00:00",
#     "modified": "2024-04-17T18:41:12.081126+00:00",
#     "id": 46379,
#     "conceptrecid": "46378",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46379",
#         "recid": 46379
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46379",
#       "html": "https://sandbox.zenodo.org/records/46379",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46379/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46379",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46379",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46379/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46379/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46379/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46379/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46379/actions/registerconceptdoi"
#     },
#     "record_id": 46379,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:37:17.668653+00:00",
#     "modified": "2024-04-17T18:37:17.721187+00:00",
#     "id": 46377,
#     "conceptrecid": "46376",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46377",
#         "recid": 46377
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46377",
#       "html": "https://sandbox.zenodo.org/records/46377",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46377/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46377",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46377",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/registerconceptdoi"
#     },
#     "record_id": 46377,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:36:58.248105+00:00",
#     "modified": "2024-04-17T18:36:58.304410+00:00",
#     "id": 46375,
#     "conceptrecid": "46374",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46375",
#         "recid": 46375
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46375",
#       "html": "https://sandbox.zenodo.org/records/46375",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46375/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46375",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46375",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46375/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46375/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46375/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46375/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46375/actions/registerconceptdoi"
#     },
#     "record_id": 46375,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:36:22.427281+00:00",
#     "modified": "2024-04-17T18:36:22.480992+00:00",
#     "id": 46373,
#     "conceptrecid": "46372",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46373",
#         "recid": 46373
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46373",
#       "html": "https://sandbox.zenodo.org/records/46373",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46373/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46373",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46373",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46373/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46373/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46373/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46373/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46373/actions/registerconceptdoi"
#     },
#     "record_id": 46373,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:35:24.944517+00:00",
#     "modified": "2024-04-17T18:35:25.000628+00:00",
#     "id": 46371,
#     "conceptrecid": "46370",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46371",
#         "recid": 46371
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46371",
#       "html": "https://sandbox.zenodo.org/records/46371",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46371/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46371",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46371",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46371/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46371/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46371/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46371/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46371/actions/registerconceptdoi"
#     },
#     "record_id": 46371,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:34:47.300466+00:00",
#     "modified": "2024-04-17T18:34:47.353537+00:00",
#     "id": 46369,
#     "conceptrecid": "46368",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46369",
#         "recid": 46369
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46369",
#       "html": "https://sandbox.zenodo.org/records/46369",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46369/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46369",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46369",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46369/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46369/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46369/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46369/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46369/actions/registerconceptdoi"
#     },
#     "record_id": 46369,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   },
#   {
#     "created": "2024-04-17T18:32:55.937605+00:00",
#     "modified": "2024-04-17T18:32:55.992151+00:00",
#     "id": 46367,
#     "conceptrecid": "46366",
#     "metadata": {
#       "access_right": "open",
#       "prereserve_doi": {
#         "doi": "10.5281/zenodo.46367",
#         "recid": 46367
#       }
#     },
#     "title": "",
#     "links": {
#       "self": "https://sandbox.zenodo.org/api/records/46367",
#       "html": "https://sandbox.zenodo.org/records/46367",
#       "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#       "files": "https://sandbox.zenodo.org/api/records/46367/files",
#       "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46367",
#       "latest_draft_html": "https://sandbox.zenodo.org/deposit/46367",
#       "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46367/actions/publish",
#       "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46367/actions/edit",
#       "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46367/actions/discard",
#       "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46367/actions/newversion",
#       "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46367/actions/registerconceptdoi"
#     },
#     "record_id": 46367,
#     "owner": 9120,
#     "files": [],
#     "state": "unsubmitted",
#     "submitted": false
#   }
# ]

# %% [markdown]
# ## Create an empty upload
#
# Response format is
#
# ```
# {
#   "created": "2024-04-17T18:37:17.668653+00:00",
#   "modified": "2024-04-17T18:37:17.721187+00:00",
#   "id": 46377,
#   "conceptrecid": "46376",
#   "metadata": {
#     "access_right": "open",
#     "prereserve_doi": {
#       "doi": "10.5281/zenodo.46377",
#       "recid": 46377
#     }
#   },
#   "title": "",
#   "links": {
#     "self": "https://sandbox.zenodo.org/api/deposit/depositions/46377",
#     "html": "https://sandbox.zenodo.org/deposit/46377",
#     "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#     "files": "https://sandbox.zenodo.org/api/deposit/depositions/46377/files",
#     "bucket": "https://sandbox.zenodo.org/api/files/a500714d-8562-45b3-9c56-b38c1d04c6b2",
#     "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46377",
#     "latest_draft_html": "https://sandbox.zenodo.org/deposit/46377",
#     "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/publish",
#     "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/edit",
#     "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/discard",
#     "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/newversion",
#     "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46377/actions/registerconceptdoi"
#   },
#   "record_id": 46377,
#   "owner": 9120,
#   "files": [],
#   "state": "unsubmitted",
#   "submitted": false
# }
# ```

# %%
request_url = BASE_URL + '/deposit/depositions'
payload = {}
response = requests.post(request_url, params=request_params, json=payload, headers=HTTP_HEADER)

print(response.status_code)
response_data = response.json()
print(json.dumps(response_data, indent = 2))

# Get the bucket URL from the response data
bucket_url = response_data['links']['bucket']
deposition_id = response_data['id']
# Out:
# 201
# {
#   "created": "2024-04-17T21:01:13.824695+00:00",
#   "modified": "2024-04-17T21:01:13.883064+00:00",
#   "id": 46404,
#   "conceptrecid": "46403",
#   "metadata": {
#     "access_right": "open",
#     "prereserve_doi": {
#       "doi": "10.5281/zenodo.46404",
#       "recid": 46404
#     }
#   },
#   "title": "",
#   "links": {
#     "self": "https://sandbox.zenodo.org/api/deposit/depositions/46404",
#     "html": "https://sandbox.zenodo.org/deposit/46404",
#     "badge": "https://sandbox.zenodo.org/badge/doi/.svg",
#     "files": "https://sandbox.zenodo.org/api/deposit/depositions/46404/files",
#     "bucket": "https://sandbox.zenodo.org/api/files/5b76780d-4b2d-4dd7-addc-bf5fb0c85069",
#     "latest_draft": "https://sandbox.zenodo.org/api/deposit/depositions/46404",
#     "latest_draft_html": "https://sandbox.zenodo.org/deposit/46404",
#     "publish": "https://sandbox.zenodo.org/api/deposit/depositions/46404/actions/publish",
#     "edit": "https://sandbox.zenodo.org/api/deposit/depositions/46404/actions/edit",
#     "discard": "https://sandbox.zenodo.org/api/deposit/depositions/46404/actions/discard",
#     "newversion": "https://sandbox.zenodo.org/api/deposit/depositions/46404/actions/newversion",
#     "registerconceptdoi": "https://sandbox.zenodo.org/api/deposit/depositions/46404/actions/registerconceptdoi"
#   },
#   "record_id": 46404,
#   "owner": 9120,
#   "files": [],
#   "state": "unsubmitted",
#   "submitted": false
# }

# %% [markdown]
# Do a PUT request to the `files` link to upload a file.
#
# Response is:
#
# ```
# {
#     'created': '2024-04-17T18:50:13.617887+00:00',
#     'updated': '2024-04-17T18:50:14.297914+00:00',
#     'version_id': '08b0eff7-c895-4ced-b0d3-f6860cae3833',
#     'key': 'lisq--flbracts36266.jpg',
#     'size': 612698,
#     'mimetype': 'image/jpeg',
#     'checksum': 'md5:07f590493c5aff505c886b2524126b0a',
#     'is_head': True,
#     'delete_marker': False,
#     'links':
#         {
#         'self': 'https://sandbox.zenodo.org/api/files/39bcbfaf-c874-48ea-b011-c01782a093f2/lisq--flbracts36266.jpg',
#         'version': 'https://sandbox.zenodo.org/api/files/39bcbfaf-c874-48ea-b011-c01782a093f2/lisq--flbracts36266.jpg?versionId=08b0eff7-c895-4ced-b0d3-f6860cae3833',
#         'uploads': 'https://sandbox.zenodo.org/api/files/39bcbfaf-c874-48ea-b011-c01782a093f2/lisq--flbracts36266.jpg?uploads'}
#         }
#   ```

# %%
filename = 'casc5-fl32936.jpg'
home_subpath = '/bioimages-highres/baskauf/'
local_file_path = home + home_subpath + filename
bucket_file_url = bucket_url + '/' + filename

''' 
The target URL is a combination of the bucket link with the desired filename
seperated by a slash.
'''
with open(local_file_path, "rb") as fp:
    r = requests.put(
        bucket_file_url,
        data=fp,
        params=request_params,
    )
print(r.status_code)
print(json.dumps(r.json(), indent = 2))
# Out:
# 201
# {
#   "created": "2024-04-17T21:01:21.219379+00:00",
#   "updated": "2024-04-17T21:01:21.894406+00:00",
#   "version_id": "73f4c367-27d9-4d0e-974f-1d6df814527c",
#   "key": "casc5-fl32936.jpg",
#   "size": 537811,
#   "mimetype": "image/jpeg",
#   "checksum": "md5:5843653a6867f6bac8c3cdaf40dd6a58",
#   "is_head": true,
#   "delete_marker": false,
#   "links": {
#     "self": "https://sandbox.zenodo.org/api/files/5b76780d-4b2d-4dd7-addc-bf5fb0c85069/casc5-fl32936.jpg",
#     "version": "https://sandbox.zenodo.org/api/files/5b76780d-4b2d-4dd7-addc-bf5fb0c85069/casc5-fl32936.jpg?versionId=73f4c367-27d9-4d0e-974f-1d6df814527c",
#     "uploads": "https://sandbox.zenodo.org/api/files/5b76780d-4b2d-4dd7-addc-bf5fb0c85069/casc5-fl32936.jpg?uploads"
#   }
# }

# %% [markdown]
# ## Add metadata

# %%
deposition_id = 46381
deposition_url = request_url + '/' + str(deposition_id)
data = {
    'metadata': {
        'title': 'Liatris squarrosa (L.) Michx. - flower - side',
        'upload_type': 'poster',
        'description': 'Live plant image of a Liatris squarrosa (L.) Michx. (scaly blazing star) flower ',
        'creators': [
            {'name': 'Baskauf, Steven J.', 'affiliation': 'Vanderbilt University'}
            ]
     }
 }
r = requests.put(deposition_url, params={'access_token': api_access_token}, data=json.dumps(data),headers=HTTP_HEADER)
r.status_code
# Out:
# 200

# %%
print(deposition_url)
# Out:
# https://sandbox.zenodo.org/api/deposit/depositions/46381

# %% [markdown]
# ## Publish the upload

# %%
publication_url = deposition_url + '/actions/publish'
r = requests.post(publication_url, params=request_params)
r.status_code
# Out:
# 202
